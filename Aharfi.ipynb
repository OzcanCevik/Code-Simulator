# %% [markdown]
# <a href="https://colab.research.google.com/github/OzcanCevik/Code-Simulator/blob/main/Aharfi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=../content/Data/data.yaml epochs=300 imgsz=640 patience=200
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 122MB/s]
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
